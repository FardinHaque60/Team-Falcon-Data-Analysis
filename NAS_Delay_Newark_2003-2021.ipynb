# %% [markdown]
# # NAS Delay in Newark International Aiport Data Analysis

# %%
import csv 

with open('Newark_All_Time_Data.csv') as csvfile:
    Newark_Data = list(csv.DictReader(csvfile))

# %% [markdown]
# ## Iterating through data to create dictionary:

# %%
temp_list1 = []
temp_list2 = []
for n in range(0, len(Newark_Data)):
    temp_dict = Newark_Data[n]
    temp_list1.append(int(temp_dict["year"]))
    try:
        temp_list2.append(float(temp_dict["nas_delay"]))
    except ValueError:
        temp_list2.append(None)

# %% [markdown]
# ## Putting dictionary in pandas datatable:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dict_data = {"year": temp_list1,
            "nas_delay": temp_list2}

usable_data = pd.DataFrame(data=dict_data)
usable_data
# Out:
#       year  nas_delay
# 0     2009      526.0
# 1     2009     4956.0
# 2     2009    30895.0
# 3     2009     3314.0
# 4     2009      639.0
# ...    ...        ...
# 2582  2018     3775.0
# 2583  2018     8435.0
# 2584  2018     5762.0
# 2585  2018    13517.0
# 2586  2018     7248.0
#
# [2587 rows x 2 columns]

# %% [markdown]
# ## Plotting data using matplotlibs:

# %%
x = usable_data.year
y = usable_data.nas_delay

# %%
plt.scatter(x,y, marker="o", alpha=0.4, s=20)
plt.xlabel("Y e a r")
plt.ylabel("D e l a y (min)")
plt.ylim(0, 140000)
plt.xticks(np.arange(min(x), max(x)+1, 2.0))
# Out:
# ([<matplotlib.axis.XTick at 0x7f930d09f3a0>,
#   <matplotlib.axis.XTick at 0x7f930d09f370>,
#   <matplotlib.axis.XTick at 0x7f930d084f70>,
#   <matplotlib.axis.XTick at 0x7f930d0f1130>,
#   <matplotlib.axis.XTick at 0x7f930d0f1640>,
#   <matplotlib.axis.XTick at 0x7f930d0f1b50>,
#   <matplotlib.axis.XTick at 0x7f930d0f60a0>,
#   <matplotlib.axis.XTick at 0x7f930d0f65b0>,
#   <matplotlib.axis.XTick at 0x7f930d0f6ac0>,
#   <matplotlib.axis.XTick at 0x7f930d0f6fd0>],
#  <a list of 10 Text major ticklabel objects>)

# %%
plt.subplot(211)
plt.scatter(x,y, marker="o", alpha=0.4, s=20)
plt.ylim(10000,50000)
plt.xlim(2015,)
plt.ylabel("D e l a y (min)")
plt.xticks(np.arange(2012, 2020, 1.0))
#top half (recent years)

plt.subplot(212)
plt.scatter(x,y, marker="o", alpha=0.4, s=20)
plt.ylim(0,10000)
plt.xlim(2015,)
plt.xlabel("Y e a r")
plt.ylabel("D e l a y (min)")
plt.xticks(np.arange(2012, 2020, 1.0))
#bottom half (recent years)
# Out:
# ([<matplotlib.axis.XTick at 0x7f930d2567c0>,
#   <matplotlib.axis.XTick at 0x7f930d256550>,
#   <matplotlib.axis.XTick at 0x7f930d24ec40>,
#   <matplotlib.axis.XTick at 0x7f930d27f400>,
#   <matplotlib.axis.XTick at 0x7f930d27f910>,
#   <matplotlib.axis.XTick at 0x7f930d27fe20>,
#   <matplotlib.axis.XTick at 0x7f930d283370>,
#   <matplotlib.axis.XTick at 0x7f930d283880>],
#  <a list of 8 Text major ticklabel objects>)
